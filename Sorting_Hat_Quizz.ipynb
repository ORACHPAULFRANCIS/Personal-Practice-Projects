# %% [markdown]
# <a href="https://colab.research.google.com/github/ORACHPAULFRANCIS/Personal-Practice-Projects/blob/main/Sorting_Hat_Quizz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The Sorting Hat Quiz - Question 1

# I have done this exercise with a lot of happiness
# I am inproving my python skills and I can feel it

print("""The Sorting Hat is a magical talking hat at
Hogwarts School of Witchcraft and Wizardry.
The hat decides which of the four "Houses"
each first-year student goes to:

🦁 Gryffindor
🦅 Ravenclaw
🦡 Hufflepuff
🐍 Slytherin""")


# Initialize house scores
gryffindor = 0
ravenclaw = 0
hufflepuff = 0
slytherin = 0

# Ask the first question
print("Q1) Do you like Dawn or Dusk?")
print("    1) Dawn")
print("    2) Dusk")

answer = int(input("Enter your answer (1 or 2): "))

# Process answer
if answer == 1:
    gryffindor += 1
    ravenclaw += 1
elif answer == 2:
    hufflepuff += 1
    slytherin += 1
else:
    print("Wrong input")

# Ask the second question

print("Q2) When I'm dead, I want people to remember me as:")
print("    1) The Good")
print("    2) The Great")
print("    3) The Wise")
print("    4) The Bold")

answer = int(input("Enter your answer (1, 2, 3 or 4): "))

# Process answer
if answer == 1:
  hufflepuff += 2
elif answer == 2:
  slytherin += 2
elif answer == 3:
  ravenclaw += 2
elif answer == 4:
  gryffindor += 2
else:
  print("Wrong input.")

# Ask the third question

print("Q3) Which kind of instrument most pleases your ear?")
print("    1) The violin")
print("    2) The trumpet")
print("    3) The piano")
print("    4) The drum")

answer = int(input("Enter your answer (1, 2, 3 or 4): "))

# Process answer

if answer == 1:
  slytherin += 4
elif answer == 2:
  hufflepuff += 4
elif answer == 3:
  ravenclaw += 4
elif answer == 4:
  gryffindor += 4
else:
  print("Wrong input.")

# Print house scores
print("\nHouse scores:")
print("Gryffindor:", gryffindor)
print("Ravenclaw:", ravenclaw)
print("Hufflepuff:", hufflepuff)
print("Slytherin:", slytherin)

# Determine the house with the highest score
houses = {
    "Gryffindor 🦁": gryffindor,
    "Ravenclaw 🦅": ravenclaw,
    "Hufflepuff 🦡": hufflepuff,
    "Slytherin 🐍": slytherin
}

# Get the house with the max score
sorted_house = max(houses, key=houses.get)

print("\nThe Sorting Hat has sorted you into...")
print(sorted_house + "!")
# Out:
# The Sorting Hat is a magical talking hat at
# Hogwarts School of Witchcraft and Wizardry.
# The hat decides which of the four "Houses"
# each first-year student goes to:
#
# 🦁 Gryffindor
# 🦅 Ravenclaw
# 🦡 Hufflepuff
# 🐍 Slytherin
# Q1) Do you like Dawn or Dusk?
#     1) Dawn
#     2) Dusk
# Enter your answer (1 or 2): 1
# Q2) When I'm dead, I want people to remember me as:
#     1) The Good
#     2) The Great
#     3) The Wise
#     4) The Bold
# Enter your answer (1, 2, 3 or 4): 2
# Q3) Which kind of instrument most pleases your ear?
#     1) The violin
#     2) The trumpet
#     3) The piano
#     4) The drum
# Enter your answer (1, 2, 3 or 4): 3
#
# House scores:
# Gryffindor: 1
# Ravenclaw: 5
# Hufflepuff: 0
# Slytherin: 2
#
# The Sorting Hat has sorted you into...
# Ravenclaw 🦅!
